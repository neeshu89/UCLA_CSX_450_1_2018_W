# %% [markdown]
# ### 1. Use Vectors to Plot these functions
#
# - $y=-4x-5$
# - $y=2x+16$
# - $y=x^2-3x+2$
# - $4x-5y=10$

# %%
xx = seq(-20, 20, by=1)


yy1 = -4*xx - 5
yy2 = 2*xx + 16
yy3 = -4*xx/5 + 2

library(repr)

options(repr.plot.width=12, repr.plot.height=6)
plot(xx, yy1, ylim=c(-10,20), xlim=c(-20,20))
points(xx, yy2)
points(xx, yy3)
abline(h=0); abline(v=0)
# Out:
# plot without title

# %% [markdown]
# ### 2. Systems of Equations
#
# Plot the solution to these systems of equations:
#
# 1. $y=-4x-5$
#    $y=2x+16$
# 1. $y=2x+16$
#    $4x-5y=10$
# 1. $y=-4x-5$
#    $4x-5y=10$

# %%
options(repr.plot.width=12, repr.plot.height=6)
plot(xx, yy1, ylim=c(-1,20), xlim=c(-10,1))
points(xx, yy2)
abline(h=0); abline(v=0)


options(repr.plot.width=12, repr.plot.height=6)
plot(xx, yy2, ylim=c(-1,20), xlim=c(-10,1))
points(xx, yy3)
abline(h=0); abline(v=0)


options(repr.plot.width=12, repr.plot.height=6)
plot(xx, yy1, ylim=c(-1,20), xlim=c(-10,1))
points(xx, yy3)
abline(h=0); abline(v=0)
# Out:
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ### 3. Define these vectors
#
# - $a = (1,2)$
# - $b = (3,0.5)$
# - $c = (\pi,e)$
# - $d=(-11,1)$
# - $e=\left(\frac{1}{4},\frac{7}{9}\right)$
# - $f=(-4,4)$

# %%
a <- c(1,2)
b <- c(3,0.5) 
c <- c(pi,exp(1))
d <- c(-11,1)
e <- c(1/4,7/9)
f <- c(-4,4)

# %% [markdown]
# ### 4. Calculate and draw a vector addition
#
# Find the result of the vector addition:
#
# $$\mathbf{g}=\mathbf{a}+\mathbf{b}+\mathbf{a}$$

# %%
vecplot <- function (v, origin=NULL, col="black", lwd=1) {
    if (is.null(origin)) {
        origin = c(0,0)
    }
    arrows(origin[1],origin[2],v[1]+origin[1],v[2]+origin[2], col=col, lwd=lwd)
}

g = a + b + a

options(repr.plot.width=12, repr.plot.height=6)
plot(NA, xlim=c(-2,8), ylim=c(-2,5), xlab="X", ylab="Y")
abline(h=0); abline(v=0)
vecplot(a, col="red")
vecplot(g, col="blue")
vecplot(b,a, col="green")
vecplot(a,a+b, col="red")
# Out:
# plot without title

# %% [markdown]
# ### 5. Find and plot the results of
#
# $$\mathbf{h}=3\mathbf{b}$$

# %%
h = 3*b

options(repr.plot.width=12, repr.plot.height=6)
plot(NA, xlim=c(-2,10), ylim=c(-1,2), xlab="X", ylab="Y")
abline(h=0); abline(v=0)
vecplot(b, col="red")
vecplot(b,b, col="red")
vecplot(b,b+b, col="red")
vecplot(h, col="blue")
# Out:
# plot without title

# %% [markdown]
# ### 6. Find the results of and plot this linear combination
#
# $$\mathbf{k}=2\mathbf{a}+3\mathbf{b}$$

# %%
k = 2*a + 3*b

options(repr.plot.width=12, repr.plot.height=6)
plot(NA, xlim=c(-1,12), ylim=c(-1,6), xlab="X", ylab="Y")
abline(h=0); abline(v=0)
vecplot(a, col="green")
vecplot(a,a, col="green")
vecplot(b,a + a, col="red")
vecplot(b,b + 2*a, col="red")
vecplot(b,2*b + 2*a, col="red")
vecplot(k, col="blue")
# Out:
# plot without title

# %% [markdown]
# ### 7. Calculate the dot products below
#
# - $\mathbf{a}^T\mathbf{b}$
# - $\mathbf{b}^T\mathbf{d}$
# - $\mathbf{c}^T\mathbf{b}$
# - $\mathbf{d}^T\mathbf{b}$
# - $\mathbf{e}^T\mathbf{a}$
# - $\mathbf{f}^T\mathbf{d}$
# - $\mathbf{a}^T\mathbf{c}$

# %% [markdown]
# ### 8. Write a function to find the magnitude of a vector.
#
# Do not use `norm`.

# %% [markdown]
# ### 9. Find the magnitude of these vectors
#
# 1. Using your function.
# 2. Using `norm`.
# 3. Demonstrate that the methods are equivalent.
#
#
# - $\mathbf{a}$
# - $\mathbf{b}$
# - $\mathbf{c}$
# - $\mathbf{d}$
# - $\mathbf{e}$
# - $\mathbf{f}$

# %% [markdown]
# ### 10. Solving Systems
#
# Use linear algebra to find the solution to these systems of equations. Plot the answers that you find along with the systems.
#
# 1. $y=-4x-5$
#    $y=2x+16$
# 1. $y=2x+16$
#    $4x-5y=10$
# 1. $y=-4x-5$
#    $4x-5y=10$

# %% [markdown]
# ### 11. Fit a function to Random Data

# %% [markdown]
# #### Generate two random points.

# %%
p1 <- runif(2); p2 <- runif(2)

# %% [markdown]
# #### Plot these two points

# %% [markdown]
# Use linear algebra to fit a line to these two points.
#
# We know that the equation looks like this
#
# $$y_i=\beta_0+\beta_1x_i$$
#
# Which we can rewrite as
#
# $$(1,x_i)^T(\beta_0, \beta_1)=y_i$$
#
# or
#
# $$\left(\begin{matrix}1&x_i\end{matrix}\right)\left(\begin{matrix}\beta_0\\ \beta_1\end{matrix}\right)=y_i$$
#
# We can use this to make
#
# $$X\beta=\mathbf{y}$$

# %% [markdown]
# ### Find $\beta$

# %% [markdown]
# Plot the two points and the line described by $\beta$.

# %% [markdown]
# ### 12. Find the line of best fit

# %%
beta_0 <- 2
beta_1 <- -3
xx <- seq(-5,5,by=.1)
n <- length(xx)
noise <- 5*runif(n)
yy = beta_0 + beta_1*xx + noise

# %%
plot(xx,yy)

# %% [markdown]
# #### Problem set up
#
# Create your matrices and vectors so that
#
# $$X\beta=\mathbf{y}$$
#
# Solve $$X^TX\beta=X^T\mathbf{y}$$

# %% [markdown]
# #### Plot the line of best fit
