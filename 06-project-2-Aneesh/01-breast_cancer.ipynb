# %%
install.packages("mlbench")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(mlbench)

# %%
data(BreastCancer)

# %%
dim(BreastCancer)
levels(BreastCancer$Class)
head(BreastCancer)
# Out:
# [1] 699  11
# [1] "benign"    "malignant"
#   Id      Cl.thickness Cell.size Cell.shape Marg.adhesion Epith.c.size
# 1 1000025 5            1         1          1             2
# 2 1002945 5            4         4          5             7
# 3 1015425 3            1         1          1             2
# 4 1016277 6            8         8          1             3
# 5 1017023 4            1         1          3             2
# 6 1017122 8            10        10         8             7
#   Bare.nuclei Bl.cromatin Normal.nucleoli Mitoses Class
# 1 1           3           1               1       benign
# 2 10          3           2               1       benign
# 3 2           3           1               1       benign
# 4 4           3           7               1       benign
# 5 1           3           1               1       benign
# 6 10          9           7               1       malignant

# %%
BreastCancer$Class <- as.integer(BreastCancer$Class == 'malignant')

# %%
BreastCancer$Id <- NULL

# %%
BreastCancer <- na.omit(BreastCancer)

# %%
pairs(BreastCancer)
# Out:
# plot without title

# %%
library(ggplot2)

# %%
hist(BreastCancer$Class, freq = FALSE)
lines(density(BreastCancer$Class))
# Out:
# Plot with title “Histogram of BreastCancer$Class”

# %%
#should use F1 score instead of Accuracy score because it's not evenly distributed - .67 accuracy with 100%
